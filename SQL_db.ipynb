# %%
# dependencies
from sqlalchemy import create_engine
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from flask import Flask, jsonify

# Bring in other notebooks
# %run finance.ipynb
# %run life.ipynb
# Out:
# The status code is 200
# {
#     "businesses": [
#         {
#             "alias": "planet-granite-san-francisco-2",
#             "categories": [
#                 {
#                     "alias": "gyms",
#                     "title": "Gyms"
#                 },
#                 {
#                     "alias": "yoga",
#                     "title": "Yoga"
#                 },
#                 {
#                     "alias": "rock_climbing",
#                     "title": "Rock Climbing"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 37.8042571851818,
#                 "longitude": -122.468032836914
#             },
#             "display_phone": "(415) 692-3434",
#             "distance": 5563.156831883973,
#             "id": "qk4sGfV2DQQs1Pe0k54-fA",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/TQlFrccOZXJwHB9WxdWsOw/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "924 Mason St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "San Francisco",
#                 "country": "US",
#                 "display_address": [
#                     "924 Mason St",
#                     "San Francisco, CA 94129"
#                 ],
#                 "state": "CA",
#                 "zip_code": "94129"
#             },
#             "name": "Planet Granite",
#             "phone": "+14156923434",
#             "rating": 4.5,
#             "review_count": 406,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/planet-granite-san-francisco-2?adjust_creative=EiLlvfl4g5qAsp36lH53qg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EiLlvfl4g5qAsp36lH53qg"
#         },
#         {
#             "alias": "mission-cliffs-climbing-and-fitness-san-francisco",
#             "categories": [
#                 {
#                     "alias": "gyms",
#                     "title": "Gyms"
#                 },
#                 {
#                     "alias": "yoga",
#                     "title": "Yoga"
#                 },
#                 {
#                     "alias": "rock_climbing",
#                     "title": "Rock Climbing"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 37.7604973,
#                 "longitude": -122.4124954
#             },
#             "display_phone": "(415) 550-0515",
#             "distance": 2109.8045311261267,
#             "id": "yR2AbNAOuzqpJfmGwV0O3g",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/MZFV0eaoqnv7EaTpByPLyw/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "2295 Harrison St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "San Francisco",
#                 "country": "US",
#                 "display_address": [
#                     "2295 Harrison St",
#                     "San Francisco, CA 94110"
#                 ],
#                 "state": "CA",
#                 "zip_code": "94110"
#             },
#             "name": "Mission Cliffs Climbing & Fitness",
#             "phone": "+14155500515",
#             "rating": 4.0,
#             "review_count": 482,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/mission-cliffs-climbing-and-fitness-san-francisco?adjust_creative=EiLlvfl4g5qAsp36lH53qg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EiLlvfl4g5qAsp36lH53qg"
#         },
#         {
#             "alias": "dogpatch-boulders-san-francisco",
#             "categories": [
#                 {
#                     "alias": "climbing",
#                     "title": "Climbing"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 37.756991,
#                 "longitude": -122.3879163
#             },
#             "display_phone": "(415) 800-8121",
#             "distance": 4303.291116740028,
#             "id": "ecoN_Wu43bsU3MZbJRZEhg",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/ruyu3NBMR3JhPZ9TWkixfQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "2573 3rd St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "San Francisco",
#                 "country": "US",
#                 "display_address": [
#                     "2573 3rd St",
#                     "San Francisco, CA 94107"
#                 ],
#                 "state": "CA",
#                 "zip_code": "94107"
#             },
#             "name": "Dogpatch Boulders",
#             "phone": "+14158008121",
#             "rating": 4.5,
#             "review_count": 141,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/dogpatch-boulders-san-francisco?adjust_creative=EiLlvfl4g5qAsp36lH53qg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EiLlvfl4g5qAsp36lH53qg"
#         },
#         {
#             "alias": "great-western-power-company-oakland",
#             "categories": [
#                 {
#                     "alias": "gyms",
#                     "title": "Gyms"
#                 },
#                 {
#                     "alias": "climbing",
#                     "title": "Climbing"
#                 },
#                 {
#                     "alias": "healthtrainers",
#                     "title": "Trainers"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 37.8097783,
#                 "longitude": -122.2701707
#             },
#             "display_phone": "(510) 452-2022",
#             "distance": 15590.205879396432,
#             "id": "NNloS0Q6nDRX4V4x0MaC6g",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/xcKZuABkxWJKfTOaLlgZJA/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "520 20th St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Oakland",
#                 "country": "US",
#                 "display_address": [
#                     "520 20th St",
#                     "Oakland, CA 94620"
#                 ],
#                 "state": "CA",
#                 "zip_code": "94620"
#             },
#             "name": "Great Western Power Company",
#             "phone": "+15104522022",
#             "rating": 4.0,
#             "review_count": 158,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/great-western-power-company-oakland?adjust_creative=EiLlvfl4g5qAsp36lH53qg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EiLlvfl4g5qAsp36lH53qg"
#         },
#         {
#             "alias": "berkeley-ironworks-climbing-and-fitness-club-berkeley",
#             "categories": [
#                 {
#                     "alias": "gyms",
#                     "title": "Gyms"
#                 },
#                 {
#                     "alias": "healthtrainers",
#                     "title": "Trainers"
#                 },
#                 {
#                     "alias": "climbing",
#                     "title": "Climbing"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 37.85071,
#                 "longitude": -122.2933
#             },
#             "display_phone": "(510) 981-9900",
#             "distance": 16117.040965042312,
#             "id": "e8qcVa63akVtgO-FFieb3Q",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/kVD3KV9tK5A7HrRt8BtTLQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "800 Potter St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Berkeley",
#                 "country": "US",
#                 "display_address": [
#                     "800 Potter St",
#                     "Berkeley, CA 94710"
#                 ],
#                 "state": "CA",
#                 "zip_code": "94710"
#             },
#             "name": "Berkeley Ironworks Climbing & Fitness Club",
#             "phone": "+15109819900",
#             "rating": 4.0,
#             "review_count": 315,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/berkeley-ironworks-climbing-and-fitness-club-berkeley?adjust_creative=EiLlvfl4g5qAsp36lH53qg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EiLlvfl4g5qAsp36lH53qg"
#         },
#         {
#             "alias": "fight-for-air-climb-san-francisco",
#             "categories": [
#                 {
#                     "alias": "climbing",
#                     "title": "Climbing"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 37.79226,
#                 "longitude": -122.40348
#             },
#             "display_phone": "(415) 392-1697",
#             "distance": 4508.273054484868,
#             "id": "1AJ94KpRhHpKO4Dq9AuURg",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/V21INH-ythkv5qcnIvQ7sA/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "555 California St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "San Francisco",
#                 "country": "US",
#                 "display_address": [
#                     "555 California St",
#                     "San Francisco, CA 94104"
#                 ],
#                 "state": "CA",
#                 "zip_code": "94104"
#             },
#             "name": "Fight for Air Climb",
#             "phone": "+14153921697",
#             "rating": 5.0,
#             "review_count": 6,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/fight-for-air-climb-san-francisco?adjust_creative=EiLlvfl4g5qAsp36lH53qg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EiLlvfl4g5qAsp36lH53qg"
#         },
#         {
#             "alias": "bridges-rock-gym-el-cerrito",
#             "categories": [
#                 {
#                     "alias": "yoga",
#                     "title": "Yoga"
#                 },
#                 {
#                     "alias": "gyms",
#                     "title": "Gyms"
#                 },
#                 {
#                     "alias": "rock_climbing",
#                     "title": "Rock Climbing"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 37.90005,
#                 "longitude": -122.30727
#             },
#             "display_phone": "(510) 525-5635",
#             "distance": 19165.875267686737,
#             "id": "p6L53V8l3R2PmESjULYyzA",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/5B2juOyx0wM2jpYNxV_vkQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "5635 San Diego St",
#                 "address2": null,
#                 "address3": "",
#                 "city": "El Cerrito",
#                 "country": "US",
#                 "display_address": [
#                     "5635 San Diego St",
#                     "El Cerrito, CA 94530"
#                 ],
#                 "state": "CA",
#                 "zip_code": "94530"
#             },
#             "name": "Bridges Rock Gym",
#             "phone": "+15105255635",
#             "rating": 4.5,
#             "review_count": 260,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/bridges-rock-gym-el-cerrito?adjust_creative=EiLlvfl4g5qAsp36lH53qg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EiLlvfl4g5qAsp36lH53qg"
#         },
#         {
#             "alias": "outdoor-adventure-club-san-francisco",
#             "categories": [
#                 {
#                     "alias": "rafting",
#                     "title": "Rafting/Kayaking"
#                 },
#                 {
#                     "alias": "hiking",
#                     "title": "Hiking"
#                 },
#                 {
#                     "alias": "rock_climbing",
#                     "title": "Rock Climbing"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 37.7935906,
#                 "longitude": -122.4214528
#             },
#             "display_phone": "(415) 377-1195",
#             "distance": 3874.4159732083162,
#             "id": "rLSLDG4weTlqnT6w_0UUQg",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/MsCg83vvvw2FKXrOONAb9g/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1819 Polk St",
#                 "address2": "Ste 222",
#                 "address3": "",
#                 "city": "San Francisco",
#                 "country": "US",
#                 "display_address": [
#                     "1819 Polk St",
#                     "Ste 222",
#                     "San Francisco, CA 94109"
#                 ],
#                 "state": "CA",
#                 "zip_code": "94109"
#             },
#             "name": "Outdoor Adventure Club",
#             "phone": "+14153771195",
#             "rating": 5.0,
#             "review_count": 41,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/outdoor-adventure-club-san-francisco?adjust_creative=EiLlvfl4g5qAsp36lH53qg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EiLlvfl4g5qAsp36lH53qg"
#         },
#         {
#             "alias": "oaktown-boulders-oakland-2",
#             "categories": [
#                 {
#                     "alias": "climbing",
#                     "title": "Climbing"
#                 },
#                 {
#                     "alias": "gyms",
#                     "title": "Gyms"
#                 },
#                 {
#                     "alias": "summer_camps",
#                     "title": "Summer Camps"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 37.77834,
#                 "longitude": -122.23313
#             },
#             "display_phone": "(510) 316-3881",
#             "distance": 17953.30007314996,
#             "id": "udqmgmhjXskeUrZ-Gtdxxg",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/WvB3rPCTriEMA5FASOW6Cg/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "2744 E 11th St",
#                 "address2": "Ste D04",
#                 "address3": "",
#                 "city": "Oakland",
#                 "country": "US",
#                 "display_address": [
#                     "2744 E 11th St",
#                     "Ste D04",
#                     "Oakland, CA 94601"
#                 ],
#                 "state": "CA",
#                 "zip_code": "94601"
#             },
#             "name": "Oaktown Boulders",
#             "phone": "+15103163881",
#             "rating": 5.0,
#             "review_count": 13,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/oaktown-boulders-oakland-2?adjust_creative=EiLlvfl4g5qAsp36lH53qg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EiLlvfl4g5qAsp36lH53qg"
#         },
#         {
#             "alias": "saano-adventures-san-francisco",
#             "categories": [
#                 {
#                     "alias": "hiking",
#                     "title": "Hiking"
#                 },
#                 {
#                     "alias": "rock_climbing",
#                     "title": "Rock Climbing"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 37.7648391723633,
#                 "longitude": -122.394752502441
#             },
#             "display_phone": "(415) 890-5209",
#             "distance": 3329.753807159828,
#             "id": "4nzQrjWcQ9yqkvspnzQWcg",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/gZ9N3YcpeHEP36BZ_gdrjg/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": null,
#                 "address2": null,
#                 "address3": "",
#                 "city": "San Francisco",
#                 "country": "US",
#                 "display_address": [
#                     "San Francisco, CA 94107"
#                 ],
#                 "state": "CA",
#                 "zip_code": "94107"
#             },
#             "name": "Saano Adventures",
#             "phone": "+14158905209",
#             "rating": 5.0,
#             "review_count": 22,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/saano-adventures-san-francisco?adjust_creative=EiLlvfl4g5qAsp36lH53qg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EiLlvfl4g5qAsp36lH53qg"
#         },
#         {
#             "alias": "house-of-air-san-francisco",
#             "categories": [
#                 {
#                     "alias": "trampoline",
#                     "title": "Trampoline Parks"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 37.804902,
#                 "longitude": -122.468805
#             },
#             "display_phone": "(415) 345-9675",
#             "distance": 5659.1935914157375,
#             "id": "KmWLtMjfw3agYm4fcJRzSA",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/KyKZIz1bhNxWOkcwC7UzTA/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "926 Mason St",
#                 "address2": null,
#                 "address3": "",
#                 "city": "San Francisco",
#                 "country": "US",
#                 "display_address": [
#                     "926 Mason St",
#                     "San Francisco, CA 94129"
#                 ],
#                 "state": "CA",
#                 "zip_code": "94129"
#             },
#             "name": "House of Air",
#             "phone": "+14153459675",
#             "rating": 3.5,
#             "review_count": 508,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/house-of-air-san-francisco?adjust_creative=EiLlvfl4g5qAsp36lH53qg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EiLlvfl4g5qAsp36lH53qg"
#         },
#         {
#             "alias": "glen-canyon-park-san-francisco",
#             "categories": [
#                 {
#                     "alias": "parks",
#                     "title": "Parks"
#                 },
#                 {
#                     "alias": "rock_climbing",
#                     "title": "Rock Climbing"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 37.7351160199868,
#                 "longitude": -122.439943626984
#             },
#             "display_phone": "",
#             "distance": 2883.4117472625567,
#             "id": "qzZGsP267MGoy-YNORgaSw",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/02XhkDaBAaU0_SMcN1Jzag/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "Bosworth St",
#                 "address2": null,
#                 "address3": "",
#                 "city": "San Francisco",
#                 "country": "US",
#                 "display_address": [
#                     "Bosworth St",
#                     "San Francisco, CA 94131"
#                 ],
#                 "state": "CA",
#                 "zip_code": "94131"
#             },
#             "name": "Glen Canyon Park",
#             "phone": "",
#             "rating": 4.5,
#             "review_count": 121,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/glen-canyon-park-san-francisco?adjust_creative=EiLlvfl4g5qAsp36lH53qg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EiLlvfl4g5qAsp36lH53qg"
#         },
#         {
#             "alias": "fort-miley-adventure-challenge-course-san-francisco",
#             "categories": [
#                 {
#                     "alias": "challengecourses",
#                     "title": "Challenge Courses"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 37.7209249,
#                 "longitude": -122.4770633
#             },
#             "display_phone": "(415) 405-3737",
#             "distance": 5666.059301862639,
#             "id": "4t68VQ_EB88jn-EEczUQTQ",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/6w2oP9A6gjV_TfnZtSkeNQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1600 Holloway Ave",
#                 "address2": "HSS 307",
#                 "address3": "",
#                 "city": "San Francisco",
#                 "country": "US",
#                 "display_address": [
#                     "1600 Holloway Ave",
#                     "HSS 307",
#                     "San Francisco, CA 94121"
#                 ],
#                 "state": "CA",
#                 "zip_code": "94121"
#             },
#             "name": "Fort Miley Adventure Challenge Course",
#             "phone": "+14154053737",
#             "rating": 4.0,
#             "review_count": 34,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/fort-miley-adventure-challenge-course-san-francisco?adjust_creative=EiLlvfl4g5qAsp36lH53qg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EiLlvfl4g5qAsp36lH53qg"
#         },
#         {
#             "alias": "grandview-park-san-francisco",
#             "categories": [
#                 {
#                     "alias": "parks",
#                     "title": "Parks"
#                 },
#                 {
#                     "alias": "hiking",
#                     "title": "Hiking"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 37.75627,
#                 "longitude": -122.47127
#             },
#             "display_phone": "(415) 831-6331",
#             "distance": 3104.974447947755,
#             "id": "dvUv35RQlpjA4rHzqJ_MzQ",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/Q3ziPhub-MLEnl2irEPDtQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1705 14th Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "San Francisco",
#                 "country": "US",
#                 "display_address": [
#                     "1705 14th Ave",
#                     "San Francisco, CA 94122"
#                 ],
#                 "state": "CA",
#                 "zip_code": "94122"
#             },
#             "name": "Grandview Park",
#             "phone": "+14158316331",
#             "rating": 5.0,
#             "review_count": 317,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/grandview-park-san-francisco?adjust_creative=EiLlvfl4g5qAsp36lH53qg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EiLlvfl4g5qAsp36lH53qg"
#         },
#         {
#             "alias": "batters-box-sf-san-francisco-2",
#             "categories": [
#                 {
#                     "alias": "battingcages",
#                     "title": "Batting Cages"
#                 },
#                 {
#                     "alias": "daycamps",
#                     "title": "Day Camps"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 37.805594,
#                 "longitude": -122.469092
#             },
#             "display_phone": "(707) 412-8228",
#             "distance": 5738.41244052271,
#             "id": "AbQMa5Frk1I8l9B-JxJ7qA",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/40C5U6V5ibm2Ywg-0ACdPA/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "933 Old Mason St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "San Francisco",
#                 "country": "US",
#                 "display_address": [
#                     "933 Old Mason St",
#                     "San Francisco, CA 94129"
#                 ],
#                 "state": "CA",
#                 "zip_code": "94129"
#             },
#             "name": "Batter's Box SF",
#             "phone": "+17074128228",
#             "rating": 4.5,
#             "review_count": 47,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/batters-box-sf-san-francisco-2?adjust_creative=EiLlvfl4g5qAsp36lH53qg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EiLlvfl4g5qAsp36lH53qg"
#         },
#         {
#             "alias": "mortar-rock-park-berkeley",
#             "categories": [
#                 {
#                     "alias": "rock_climbing",
#                     "title": "Rock Climbing"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 37.89325,
#                 "longitude": -122.27235
#             },
#             "display_phone": "(510) 981-6637",
#             "distance": 20598.793444853967,
#             "id": "JeirbclZsZT9rvfIMXweFA",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/7I7gJ2PU7-be90xKd5eqRA/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "901 Indian Rock Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Berkeley",
#                 "country": "US",
#                 "display_address": [
#                     "901 Indian Rock Ave",
#                     "Berkeley, CA 94707"
#                 ],
#                 "state": "CA",
#                 "zip_code": "94707"
#             },
#             "name": "Mortar Rock Park",
#             "phone": "+15109816637",
#             "rating": 5.0,
#             "review_count": 5,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/mortar-rock-park-berkeley?adjust_creative=EiLlvfl4g5qAsp36lH53qg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EiLlvfl4g5qAsp36lH53qg"
#         },
#         {
#             "alias": "sports-basement-san-francisco",
#             "categories": [
#                 {
#                     "alias": "outdoorgear",
#                     "title": "Outdoor Gear"
#                 },
#                 {
#                     "alias": "bikerentals",
#                     "title": "Bike Rentals"
#                 },
#                 {
#                     "alias": "bikes",
#                     "title": "Bikes"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 37.8027313175243,
#                 "longitude": -122.459750175476
#             },
#             "display_phone": "(415) 934-2900",
#             "distance": 5082.3639086080875,
#             "id": "k4m6f3xsxlfZD0OoPKp_cQ",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/-iYexxNP46T1Xc-YUPU1Fg/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "610 Old Mason St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "San Francisco",
#                 "country": "US",
#                 "display_address": [
#                     "610 Old Mason St",
#                     "San Francisco, CA 94129"
#                 ],
#                 "state": "CA",
#                 "zip_code": "94129"
#             },
#             "name": "Sports Basement",
#             "phone": "+14159342900",
#             "price": "$$",
#             "rating": 4.5,
#             "review_count": 1191,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/sports-basement-san-francisco?adjust_creative=EiLlvfl4g5qAsp36lH53qg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EiLlvfl4g5qAsp36lH53qg"
#         },
#         {
#             "alias": "entangle-and-sway-san-francisco-2",
#             "categories": [
#                 {
#                     "alias": "aerialfitness",
#                     "title": "Aerial Fitness"
#                 },
#                 {
#                     "alias": "poledancingclasses",
#                     "title": "Pole Dancing Classes"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 37.78557,
#                 "longitude": -122.44308
#             },
#             "display_phone": "(415) 854-2466",
#             "distance": 2811.581160126312,
#             "id": "CdzZ7g9rB6EwCt75soXufA",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/at3oS701wZkIAJctcYNZhw/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "2791 Bush St",
#                 "address2": null,
#                 "address3": "",
#                 "city": "San Francisco",
#                 "country": "US",
#                 "display_address": [
#                     "2791 Bush St",
#                     "San Francisco, CA 94115"
#                 ],
#                 "state": "CA",
#                 "zip_code": "94115"
#             },
#             "name": "Entangle & Sway",
#             "phone": "+14158542466",
#             "rating": 4.5,
#             "review_count": 54,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/entangle-and-sway-san-francisco-2?adjust_creative=EiLlvfl4g5qAsp36lH53qg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EiLlvfl4g5qAsp36lH53qg"
#         },
#         {
#             "alias": "golden-gate-wall-oakland",
#             "categories": [
#                 {
#                     "alias": "climbing",
#                     "title": "Climbing"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 37.84843,
#                 "longitude": -122.2388533
#             },
#             "display_phone": "",
#             "distance": 19888.743986718644,
#             "id": "rBwZmEx1NRuWBpaSg1fbug",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/8WKuRssU9X8xCxU47GlUaQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "5748 Golden Gate Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Oakland",
#                 "country": "US",
#                 "display_address": [
#                     "5748 Golden Gate Ave",
#                     "Oakland, CA 94618"
#                 ],
#                 "state": "CA",
#                 "zip_code": "94618"
#             },
#             "name": "Golden Gate Wall",
#             "phone": "",
#             "rating": 4.0,
#             "review_count": 3,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/golden-gate-wall-oakland?adjust_creative=EiLlvfl4g5qAsp36lH53qg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EiLlvfl4g5qAsp36lH53qg"
#         },
#         {
#             "alias": "indian-rock-park-berkeley",
#             "categories": [
#                 {
#                     "alias": "parks",
#                     "title": "Parks"
#                 },
#                 {
#                     "alias": "climbing",
#                     "title": "Climbing"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 37.8921780492205,
#                 "longitude": -122.272253036499
#             },
#             "display_phone": "",
#             "distance": 20519.62046543498,
#             "id": "HY_iChyzX_odu0T7MAwmTw",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/hr45srcyhGVIQOdxBcVV8g/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "950 Indian Rock Ave",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Berkeley",
#                 "country": "US",
#                 "display_address": [
#                     "950 Indian Rock Ave",
#                     "Berkeley, CA 94707"
#                 ],
#                 "state": "CA",
#                 "zip_code": "94707"
#             },
#             "name": "Indian Rock Park",
#             "phone": "",
#             "rating": 4.5,
#             "review_count": 206,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/indian-rock-park-berkeley?adjust_creative=EiLlvfl4g5qAsp36lH53qg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EiLlvfl4g5qAsp36lH53qg"
#         }
#     ],
#     "region": {
#         "center": {
#             "latitude": 37.76089938976322,
#             "longitude": -122.43644714355469
#         }
#     },
#     "total": 572
# }

# %%
# Create engine 
engine = create_engine("sqlite:///future.sqlite")
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)
# all tables are deleted
Base.metadata.drop_all(engine)

# %%
# Convert to sql 
cities_gdp.to_sql(name="cities_gdp", con=engine)
cpi_df.to_sql(name="cpi", con=engine)
yelp_df.to_sql(name="yelp", con=engine)
